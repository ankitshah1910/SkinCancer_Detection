# %% [markdown]
# # **Problem Statement:**
#
# *   To build a CNN based model which can accurately detect melanoma.
# *   Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths
# *   A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis

# %%
#Importing all the important libraries
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
# Mount the google drive:
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ### **Data Reading/Data Understanding**

# %%
# Defining the path for train and test images
data_dir_train = pathlib.Path("/content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path("/content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Test")

# %% [markdown]
# **Data Description:**
#
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### **Dataset Creation**

# %%
# Define some parameters for the loader:
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,
                                                               seed=123,
                                                               validation_split= 0.2,
                                                               subset= 'training',
                                                               image_size=(img_height,img_width),
                                                               batch_size = batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,
                                                              seed=123,
                                                              validation_split= 0.2,
                                                              subset= 'validation',
                                                              image_size=(img_height,img_width),
                                                              batch_size = batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### **Dataset visualisation**

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
for i in range(9): 
  plt.subplot(3, 3, i + 1)
  image = plt.imread(str(list(data_dir_train.glob(class_names[i]+'/*.jpg'))[1]))
  plt.title(class_names[i])
  plt.imshow(image)

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.
#
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### **Model Building & training :**

# %%
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      2432
#
#  conv2d_1 (Conv2D)           (None, 180, 180, 32)      25632
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 90, 90, 32)        25632
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 45, 45, 64)        51264
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 22, 22, 64)        102464
#
#  max_pooling2d_3 (MaxPooling  (None, 11, 11, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 11, 11, 64)        0
#
#  flatten (Flatten)           (None, 7744)              0
#
#  dense (Dense)               (None, 9)                 69705
#
# =================================================================
# Total params: 277,129
# Trainable params: 277,129
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 56/56 [==============================] - 23s 135ms/step - loss: 2.0588 - accuracy: 0.2059 - val_loss: 2.0304 - val_accuracy: 0.2058
# Epoch 2/20
# 56/56 [==============================] - 4s 76ms/step - loss: 2.0179 - accuracy: 0.2210 - val_loss: 1.9437 - val_accuracy: 0.2371
# Epoch 3/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.9025 - accuracy: 0.2840 - val_loss: 1.9006 - val_accuracy: 0.2707
# Epoch 4/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.8197 - accuracy: 0.3203 - val_loss: 1.7773 - val_accuracy: 0.3624
# Epoch 5/20
# 56/56 [==============================] - 4s 79ms/step - loss: 1.7741 - accuracy: 0.3371 - val_loss: 1.8674 - val_accuracy: 0.3177
# Epoch 6/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.6901 - accuracy: 0.3873 - val_loss: 1.7048 - val_accuracy: 0.3848
# Epoch 7/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.5972 - accuracy: 0.4180 - val_loss: 1.5554 - val_accuracy: 0.4631
# Epoch 8/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.5695 - accuracy: 0.4269 - val_loss: 1.5446 - val_accuracy: 0.4609
# Epoch 9/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.5286 - accuracy: 0.4431 - val_loss: 1.6341 - val_accuracy: 0.4318
# Epoch 10/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.5302 - accuracy: 0.4598 - val_loss: 1.4838 - val_accuracy: 0.4832
# Epoch 11/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.4181 - accuracy: 0.4927 - val_loss: 1.5506 - val_accuracy: 0.4720
# Epoch 12/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.3625 - accuracy: 0.5112 - val_loss: 1.5411 - val_accuracy: 0.4586
# Epoch 13/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.3074 - accuracy: 0.5352 - val_loss: 1.5762 - val_accuracy: 0.4586
# Epoch 14/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.2594 - accuracy: 0.5619 - val_loss: 1.5716 - val_accuracy: 0.4877
# Epoch 15/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.2127 - accuracy: 0.5658 - val_loss: 1.7397 - val_accuracy: 0.4653
# Epoch 16/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.1597 - accuracy: 0.5943 - val_loss: 1.6696 - val_accuracy: 0.4720
# Epoch 17/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.1358 - accuracy: 0.5960 - val_loss: 1.5856 - val_accuracy: 0.4810
# Epoch 18/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.0190 - accuracy: 0.6412 - val_loss: 1.6808 - val_accuracy: 0.5101
# Epoch 19/20
# 56/56 [==============================] - 4s 76ms/step - loss: 1.0238 - accuracy: 0.6311 - val_loss: 1.7738 - val_accuracy: 0.4944
# Epoch 20/20
# 56/56 [==============================] - 4s 76ms/step - loss: 0.9795 - accuracy: 0.6429 - val_loss: 1.8803 - val_accuracy: 0.4989

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **Findings on the base model**
#
# - The training accuracy is more as compared to validation accuracy, so we can say that the model is overfitting.
#
# - Also we can see the difference in loss functions in training & validation around the 8-9th epoch
#
# - The accuracy is just around 75-80% because there are enough features to remember the pattern.
#
# - Lets further train model with increased epochs to check of this issue gets resolved.

# %% [markdown]
# Data augumentation strategy

# %%
data_augument = keras.Sequential([
                             layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                             layers.experimental.preprocessing.RandomRotation(0.2, fill_mode='reflect'),
                             layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=(0.2, 0.3), fill_mode='reflect')
])

# %%
plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(data_augument(images)[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ### Create the model, compile and train the model

# %%
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([ data_augument,
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ### Compiling the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
epochs=30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 7s 91ms/step - loss: 2.0453 - accuracy: 0.2193 - val_loss: 2.1437 - val_accuracy: 0.2304
# Epoch 2/30
# 56/56 [==============================] - 5s 85ms/step - loss: 1.9291 - accuracy: 0.2612 - val_loss: 1.8986 - val_accuracy: 0.2841
# Epoch 3/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.8692 - accuracy: 0.2946 - val_loss: 1.7994 - val_accuracy: 0.3691
# Epoch 4/30
# 56/56 [==============================] - 5s 85ms/step - loss: 1.7982 - accuracy: 0.3471 - val_loss: 1.6606 - val_accuracy: 0.4004
# Epoch 5/30
# 56/56 [==============================] - 5s 85ms/step - loss: 1.7345 - accuracy: 0.3610 - val_loss: 1.7264 - val_accuracy: 0.3691
# Epoch 6/30
# 56/56 [==============================] - 5s 85ms/step - loss: 1.7390 - accuracy: 0.3594 - val_loss: 1.6125 - val_accuracy: 0.4094
# Epoch 7/30
# 56/56 [==============================] - 5s 85ms/step - loss: 1.6195 - accuracy: 0.4051 - val_loss: 1.5583 - val_accuracy: 0.4653
# Epoch 8/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.5738 - accuracy: 0.4381 - val_loss: 1.5667 - val_accuracy: 0.4340
# Epoch 9/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.5459 - accuracy: 0.4537 - val_loss: 1.4978 - val_accuracy: 0.4720
# Epoch 10/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.3805 - accuracy: 0.1931 - val_loss: 2.0366 - val_accuracy: 0.1924
# Epoch 11/30
# 56/56 [==============================] - 5s 85ms/step - loss: 1.9552 - accuracy: 0.2511 - val_loss: 1.8567 - val_accuracy: 0.3356
# Epoch 12/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.9267 - accuracy: 0.2773 - val_loss: 1.9048 - val_accuracy: 0.2819
# Epoch 13/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.7991 - accuracy: 0.3315 - val_loss: 2.0513 - val_accuracy: 0.3266
# Epoch 14/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.7034 - accuracy: 0.3733 - val_loss: 1.7263 - val_accuracy: 0.3870
# Epoch 15/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.7256 - accuracy: 0.3638 - val_loss: 1.7521 - val_accuracy: 0.3714
# Epoch 16/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.6634 - accuracy: 0.4023 - val_loss: 1.6374 - val_accuracy: 0.4206
# Epoch 17/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.5959 - accuracy: 0.4358 - val_loss: 1.6169 - val_accuracy: 0.4139
# Epoch 18/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.5951 - accuracy: 0.4224 - val_loss: 1.6038 - val_accuracy: 0.4072
# Epoch 19/30
# 56/56 [==============================] - 5s 89ms/step - loss: 1.6102 - accuracy: 0.4280 - val_loss: 1.5416 - val_accuracy: 0.4541
# Epoch 20/30
# 56/56 [==============================] - 5s 85ms/step - loss: 1.5285 - accuracy: 0.4487 - val_loss: 1.5089 - val_accuracy: 0.4743
# Epoch 21/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.5603 - accuracy: 0.4369 - val_loss: 1.6476 - val_accuracy: 0.4474
# Epoch 22/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.5574 - accuracy: 0.4280 - val_loss: 1.5222 - val_accuracy: 0.4609
# Epoch 23/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.5588 - accuracy: 0.4431 - val_loss: 1.5363 - val_accuracy: 0.4519
# Epoch 24/30
# 56/56 [==============================] - 5s 87ms/step - loss: 1.5400 - accuracy: 0.4481 - val_loss: 1.5494 - val_accuracy: 0.4653
# Epoch 25/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.5009 - accuracy: 0.4643 - val_loss: 1.4902 - val_accuracy: 0.4855
# Epoch 26/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.4552 - accuracy: 0.4844 - val_loss: 1.4891 - val_accuracy: 0.4832
# Epoch 27/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.4664 - accuracy: 0.4727 - val_loss: 1.4673 - val_accuracy: 0.4877
# Epoch 28/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.4769 - accuracy: 0.4727 - val_loss: 1.5140 - val_accuracy: 0.4832
# Epoch 29/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.4803 - accuracy: 0.4715 - val_loss: 1.6157 - val_accuracy: 0.4049
# Epoch 30/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.4750 - accuracy: 0.4754 - val_loss: 1.4398 - val_accuracy: 0.5011

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **Finding from Second Model**
#
# - The model is improved as the problem of overfitting is eradicated from it.
#
# - But there is scope of improvement in the accuracy of the model. For this we can try increasing the epochs and retrain the model.

# %% [markdown]
# #### **Find the distribution of classes in the training dataset.**
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
path_list=[]
lesion_list=[]
for i in class_names:
      
    for j in data_dir_train.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df.Label.value_counts()
# Out:
# pigmented benign keratosis    462
# melanoma                      438
# basal cell carcinoma          376
# nevus                         357
# squamous cell carcinoma       181
# vascular lesion               139
# actinic keratosis             114
# dermatofibroma                 95
# seborrheic keratosis           77
# Name: Label, dtype: int64

# %% [markdown]
# #### Class imbalance findings:
# #### - **seborrheic keratosis** class has the least number of samples.
# #### - **pigmented benign keratosis** & **melanoma** classes dominate the data in terms proportionate number of samples.

# %% [markdown]
# #### **Rectify the class imbalance**

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Augmentor in /usr/local/lib/python3.7/dist-packages (0.2.10)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
import Augmentor
import os
train_path = "/content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train"

for i in class_names:
  p = Augmentor.Pipeline(train_path,save_format='jpg')
  p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
  p.sample(500)
# Out:
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F559E9DED10>: 100%|██████████| 500/500 [00:37<00:00, 13.40 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F559EA77910>: 100%|██████████| 500/500 [00:43<00:00, 11.47 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=3072x2304 at 0x7F56303A3650>: 100%|██████████| 500/500 [00:46<00:00, 10.80 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F559CF7B610>: 100%|██████████| 500/500 [00:41<00:00, 11.91 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F56302FAD90>: 100%|██████████| 500/500 [00:43<00:00, 11.59 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F559EA95310>: 100%|██████████| 500/500 [00:45<00:00, 11.02 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F559EB93C10>: 100%|██████████| 500/500 [00:43<00:00, 11.51 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F559EA89B10>: 100%|██████████| 500/500 [00:40<00:00, 12.23 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F562EAEC990>: 100%|██████████| 500/500 [00:45<00:00, 11.06 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
data_dir = pathlib.Path("/content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output/")
image_count_train = len(list(data_dir.glob('*/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# Lets see the distribution of augmented data after adding new images to the original training data.

# %%
for i in class_names:
    for j in data_dir.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
new_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
new_df
# Out:
#                                                    Path              Label
# 0     /content/gdrive/MyDrive/Skin cancer ISIC The I...  actinic keratosis
# 1     /content/gdrive/MyDrive/Skin cancer ISIC The I...  actinic keratosis
# 2     /content/gdrive/MyDrive/Skin cancer ISIC The I...  actinic keratosis
# 3     /content/gdrive/MyDrive/Skin cancer ISIC The I...  actinic keratosis
# 4     /content/gdrive/MyDrive/Skin cancer ISIC The I...  actinic keratosis
# ...                                                 ...                ...
# 6734  /content/gdrive/MyDrive/Skin cancer ISIC The I...    vascular lesion
# 6735  /content/gdrive/MyDrive/Skin cancer ISIC The I...    vascular lesion
# 6736  /content/gdrive/MyDrive/Skin cancer ISIC The I...    vascular lesion
# 6737  /content/gdrive/MyDrive/Skin cancer ISIC The I...    vascular lesion
# 6738  /content/gdrive/MyDrive/Skin cancer ISIC The I...    vascular lesion
#
# [6739 rows x 2 columns]

# %%
new_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    1394
# melanoma                      1305
# basal cell carcinoma          1171
# nevus                         1088
# squamous cell carcinoma        544
# vascular lesion                443
# actinic keratosis              315
# dermatofibroma                 257
# seborrheic keratosis           222
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
data_dir_train1=pathlib.Path("/content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output")
image_count_train1 = len(list(data_dir_train1.glob('*/*.jpg')))
print(image_count_train1)
# Out:
# 4500

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train1,
  seed=123,
  validation_split = 0.2,
  subset = "training",
  image_size=(img_height, img_width),
  batch_size=batch_size)
train_ds
# Out:
# Found 4500 files belonging to 9 classes.
# Using 3600 files for training.
# <BatchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train1,
  seed=123,
  validation_split = 0.2,
  subset = "validation",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4500 files belonging to 9 classes.
# Using 900 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## We can use Dropout layer if there is an evidence of overfitting in your findings
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 113/113 [==============================] - 20s 165ms/step - loss: 2.0304 - accuracy: 0.2178 - val_loss: 2.0576 - val_accuracy: 0.1967
# Epoch 2/20
# 113/113 [==============================] - 20s 168ms/step - loss: 1.9796 - accuracy: 0.2361 - val_loss: 1.9397 - val_accuracy: 0.2889
# Epoch 3/20
# 113/113 [==============================] - 20s 168ms/step - loss: 1.8383 - accuracy: 0.3211 - val_loss: 1.8017 - val_accuracy: 0.3678
# Epoch 4/20
# 113/113 [==============================] - 20s 167ms/step - loss: 1.6064 - accuracy: 0.4258 - val_loss: 1.6184 - val_accuracy: 0.3989
# Epoch 5/20
# 113/113 [==============================] - 20s 164ms/step - loss: 1.5315 - accuracy: 0.4406 - val_loss: 1.4955 - val_accuracy: 0.4800
# Epoch 6/20
# 113/113 [==============================] - 20s 166ms/step - loss: 1.4681 - accuracy: 0.4867 - val_loss: 1.4251 - val_accuracy: 0.5144
# Epoch 7/20
# 113/113 [==============================] - 20s 166ms/step - loss: 1.4418 - accuracy: 0.4853 - val_loss: 1.4075 - val_accuracy: 0.5011
# Epoch 8/20
# 113/113 [==============================] - 20s 165ms/step - loss: 1.4296 - accuracy: 0.4950 - val_loss: 1.4577 - val_accuracy: 0.4778
# Epoch 9/20
# 113/113 [==============================] - 19s 164ms/step - loss: 1.3786 - accuracy: 0.5272 - val_loss: 1.3793 - val_accuracy: 0.5300
# Epoch 10/20
# 113/113 [==============================] - 20s 166ms/step - loss: 1.3778 - accuracy: 0.5258 - val_loss: 1.4449 - val_accuracy: 0.5122
# Epoch 11/20
# 113/113 [==============================] - 20s 166ms/step - loss: 1.3007 - accuracy: 0.5475 - val_loss: 1.3507 - val_accuracy: 0.5322
# Epoch 12/20
# 113/113 [==============================] - 20s 165ms/step - loss: 1.2657 - accuracy: 0.5489 - val_loss: 1.3498 - val_accuracy: 0.5378
# Epoch 13/20
# 113/113 [==============================] - 20s 165ms/step - loss: 1.2056 - accuracy: 0.5833 - val_loss: 1.3185 - val_accuracy: 0.5478
# Epoch 14/20
# 113/113 [==============================] - 20s 169ms/step - loss: 1.1749 - accuracy: 0.5894 - val_loss: 1.4123 - val_accuracy: 0.5400
# Epoch 15/20
# 113/113 [==============================] - 22s 185ms/step - loss: 1.1326 - accuracy: 0.5997 - val_loss: 1.2924 - val_accuracy: 0.5556
# Epoch 16/20
# 113/113 [==============================] - 20s 165ms/step - loss: 1.0674 - accuracy: 0.6272 - val_loss: 1.2845 - val_accuracy: 0.5733
# Epoch 17/20
# 113/113 [==============================] - 20s 165ms/step - loss: 1.0068 - accuracy: 0.6531 - val_loss: 1.3343 - val_accuracy: 0.5722
# Epoch 18/20
# 113/113 [==============================] - 20s 166ms/step - loss: 0.9623 - accuracy: 0.6619 - val_loss: 1.2333 - val_accuracy: 0.5667
# Epoch 19/20
# 113/113 [==============================] - 20s 165ms/step - loss: 1.0221 - accuracy: 0.6361 - val_loss: 1.2205 - val_accuracy: 0.5900
# Epoch 20/20
#  83/113 [=====================>........] - ETA: 4s - loss: 0.9041 - accuracy: 0.6788

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Conclusions:**
# - Accuracy on training data has increased by using Augmentor library
# - The Model can be further improved by tuning the hyperparameter
# - Model is overfitting
# - The problem of overfitting can be solved by adding more layer, neurons or adding dropout layer.
